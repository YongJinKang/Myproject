# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
import time
import pandas as pd
from pprint import pprint as pp
from inspect import signature
from datetime import datetime
import warnings
warnings.filterwarnings(action = 'ignore')
# %config InlineBackend.figure_format = 'retina'
import platform
import sys
import numpy as np
import missingno as msno
import matplotlib.font_manager as fm
from matplotlib import rc
font_name = fm.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()

# %%
train= pd.read_csv('./data/train.csv')
quality=pd.read_csv('./data/sample_submission.csv')
test = pd.read_csv('./data/test.csv')
print(train.shape)
train.head()
# Out:
# (5497, 14)
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# 2  0.99176  3.05       0.52     10.9  white
# 3  0.99390  3.26       0.50     10.8  white
# 4  0.99550  3.04       0.43     10.9  white

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5497 entries, 0 to 5496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 5497 non-null   int64
#  1   quality               5497 non-null   int64
#  2   fixed acidity         5497 non-null   float64
#  3   volatile acidity      5497 non-null   float64
#  4   citric acid           5497 non-null   float64
#  5   residual sugar        5497 non-null   float64
#  6   chlorides             5497 non-null   float64
#  7   free sulfur dioxide   5497 non-null   float64
#  8   total sulfur dioxide  5497 non-null   float64
#  9   density               5497 non-null   float64
#  10  pH                    5497 non-null   float64
#  11  sulphates             5497 non-null   float64
#  12  alcohol               5497 non-null   float64
#  13  type                  5497 non-null   object
# dtypes: float64(11), int64(2), object(1)
# memory usage: 601.4+ KB

# %%
train['quality'].unique()
# Out:
# array([5, 6, 7, 8, 4, 3, 9], dtype=int64)

# %%
for col in train.columns[2:-1]:
    sns.distplot(train.loc[train[col].notnull(), col], hist=True ) #hist = False하면 히스토그램안나옴
    plt.title(col)
    plt.show()

# %% [markdown]
# ## 등급별 각 특성 평균

# %%
qualitymean=train.groupby('quality').mean()

# %%
qualitymean
# Out:
#                index  fixed acidity  volatile acidity  citric acid  \
# quality
# 3        2847.730769       7.811538          0.538077     0.266923
# 4        2692.709677       7.269892          0.447285     0.280323
# 5        2762.370805       7.329195          0.387855     0.308043
# 6        2741.139901       7.166743          0.312301     0.323411
# 7        2794.899351       7.123972          0.289724     0.332987
# 8        2466.427632       6.839474          0.292730     0.330263
# 9        2354.800000       7.420000          0.298000     0.386000
#
#          residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# quality
# 3              5.203846   0.076500            40.096154            121.461538
# 4              4.145430   0.059247            20.553763            104.811828
# 5              5.792422   0.064417            30.174217            120.370805
# 6              5.535141   0.053932            30.969578            115.357616
# 7              4.748918   0.045352            30.457251            108.178571
# 8              5.581579   0.041105            34.585526            119.421053
# 9              4.120000   0.027400            33.400000            116.000000
#
#           density        pH  sulphates    alcohol
# quality
# 3        0.995713  3.250385   0.500000  10.251923
# 4        0.994730  3.228602   0.500484  10.180376
# 5        0.995843  3.213384   0.525017   9.846875
# 6        0.994527  3.219611   0.532686  10.606015
# 7        0.993122  3.228333   0.546786  11.383864
# 8        0.992544  3.216711   0.506184  11.680921
# 9        0.991460  3.308000   0.466000  12.180000

# %%
for col1 in train.columns[1:-1]:
    ax = plt.subplots()
    ax = sns.barplot(x='quality',y=col1, data=train)
    ax.set_title('와인종별 평균')
    ax.set_xlabel('등급')
    ax.set_ylabel(col1)

# %%
for col1 in train.columns[1:-1]:
    ax = plt.subplots()
    ax = sns.barplot(x='type',y=col1, data=train)
    ax.set_title('등급별 평균')
    ax.set_xlabel('와인종')
    ax.set_ylabel(col1)

# %%
train.head()
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol   type
# 0  0.99432  3.44       0.44     10.2  white
# 1  0.99690  3.19       0.59      9.5    red
# 2  0.99176  3.05       0.52     10.9  white
# 3  0.99390  3.26       0.50     10.8  white
# 4  0.99550  3.04       0.43     10.9  white

# %% [markdown]
# ## 와인 종별로 품질은 어떠할까 ?

# %%
pd.crosstab(train.quality,train.type, margins=True)
# Out:
# type      red  white   All
# quality
# 3           9     17    26
# 4          41    145   186
# 5         571   1217  1788
# 6         535   1881  2416
# 7         169    755   924
# 8          13    139   152
# 9           0      5     5
# All      1338   4159  5497

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data = train.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
for col1 in train.columns[2:-1]:
    scatter_plot = plt.figure()
    axes1 = scatter_plot.add_subplot(1,1,1)
    axes1.scatter(train[col1], train['quality'])
    axes1.set_title('산점도')
    axes1.set_xlabel(col1)
    axes1.set_ylabel('품질')

# %%
X_train = train.iloc[:,2:]
y_train = train.iloc[:,1]
y_train.to_frame()
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           6
# ...       ...
# 5492        5
# 5493        6
# 5494        7
# 5495        5
# 5496        6
#
# [5497 rows x 1 columns]

# %%
X_test = train.iloc[:,2:]
y_test = train.iloc[:,1]
y_test.to_frame()
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           6
# ...       ...
# 5492        5
# 5493        6
# 5494        7
# 5495        5
# 5496        6
#
# [5497 rows x 1 columns]

# %%
X_train=X_train.replace('white','1')
X_train=X_train.replace('red','2')
X_test= X_test.replace('white','1')
X_test= X_test.replace('red','2')

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train,y_train)
# tree.score(X_test,y_test)
testpred=tree.predict(X_test)
print(testpred)
print(y_test)
print("훈련 세트 정확도: {:.3f}".format(tree.score(X_train,y_train)))
print("테스트 세트 정확도: {:.3f}".format(tree.score(X_test,y_test)))
# Out:
# [5 5 5 ... 7 5 6]
# 0       5
# 1       5
# 2       5
# 3       6
# 4       6
#        ..
# 5492    5
# 5493    6
# 5494    7
# 5495    5
# 5496    6
# Name: quality, Length: 5497, dtype: int64
# 훈련 세트 정확도: 1.000
# 테스트 세트 정확도: 1.000
